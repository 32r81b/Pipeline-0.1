# %%
import pandas as pd
import numpy as np
from usfull_tools import load_DS
#from catboost import Pool, CatBoostRegressor, CatBoostClassifier
#from sklearn.model_selection import train_test_split, cross_val_score
pd.options.display.max_columns = None
# %matplotlib inline

from set_vars import KAGGLE_PREFIX, debug_mode, KAGGLE_DIR, target_column, target_type, id_column

train, test = load_DS(debug_mode, KAGGLE_DIR, KAGGLE_PREFIX, '_prepare.csv')
del train

cols = pd.read_csv(KAGGLE_DIR + KAGGLE_PREFIX + '_important_columns.csv')
test = test[cols['Feature']]
test.shape
# Out:
# (1459, 44)

# %%
import pickle

with open(KAGGLE_DIR + KAGGLE_PREFIX + 'classifier.pkl', 'rb') as fid:
    model = pickle.load(fid)

y_test = model.predict(test)
predict = pd.read_csv(KAGGLE_DIR + KAGGLE_PREFIX + 'test.csv', usecols=[id_column])
predict[target_column] = y_test.astype(np.int)
predict.to_csv(KAGGLE_DIR + KAGGLE_PREFIX + 'submission.csv', index=False, sep=',')

# %%
predict
# Out:
#         Id  SalePrice
# 0     1461     130019
# 1     1462     159019
# 2     1463     173930
# 3     1464     179000
# 4     1465     234668
# 5     1466     182320
# 6     1467     188704
# 7     1468     182042
# 8     1469     175427
# 9     1470     103925
# 10    1471     204289
# 11    1472     106342
# 12    1473     115412
# 13    1474     152942
# 14    1475     138347
# 15    1476     283293
# 16    1477     229782
# 17    1478     209305
# 18    1479     252180
# 19    1480     330824
# 20    1481     278810
# 21    1482     211198
# 22    1483     156599
# 23    1484     177091
# 24    1485     201193
# 25    1486     228242
# 26    1487     259143
# 27    1488     301216
# 28    1489     196591
# 29    1490     157285
# ...    ...        ...
# 1429  2890      95617
# 1430  2891     144169
# 1431  2892      71719
# 1432  2893     101917
# 1433  2894      73648
# 1434  2895     243918
# 1435  2896     228286
# 1436  2897     177777
# 1437  2898     160000
# ...
