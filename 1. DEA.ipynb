# %% [markdown]
# # Подгружаем библиотеки и данные

# %% [markdown]
# debug_mode служит индикатором, что работа с ноутбуком идет в режиме разработчика. В этом режиме для ускорения работы будут загружаться не все записи из датасета.

# %%
import pandas as pd
import numpy as np
from DS_stat import DS_stat
from usfull_tools import load_DS
# %matplotlib inline

from set_vars import KAGGLE_PREFIX, debug_mode, KAGGLE_DIR, target_column

pd.options.display.max_columns = None

train, test = load_DS(debug_mode, KAGGLE_DIR, KAGGLE_PREFIX)

DS_stat(train, target_column)
# Out:
# Shape: 891  *  12
# First 5 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket       Fare Cabin Embarked
# 0      0         A/5 21171   7.250000   NaN        S
# 1      0          PC 17599  71.312500   C85        C
# 2      0  STON/O2. 3101282   7.925781   NaN        S
# 3      0            113803  53.093750  C123        S
# 4      0            373450   8.046875   NaN        S
# ------------------ PassengerId ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  891  -  1  ( 0.11 %)
# Unique values: 891
# Min / Max: 1  /  891
# 5% / 95% percentile: 45.5  /  846.5
# ------------------ Survived ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  0  -  549  ( 61.62 %)
# Unique values: 2
# Min / Max: 0  /  1
# ------------------ Pclass ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  3  -  491  ( 55.11 %)
# Unique values: 3
# Min / Max: 1  /  3
# ------------------ Name ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  Kirkland, Rev. Charles Leonard  -  1  ( 0.11 %)
# Unique values of: 891  ( 100.0 %)
#
# ------------------ Sex ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  male  -  577  ( 64.76 %)
# Unique values of: 2  ( 0.22 %)
# male      577
# female    314
# Name: Sex, dtype: int64
# ------------------ Age ---------------------
# Nan values:  177  ( 19.87 %)
# Most frequent:  24.0  -  30  ( 4.2 %)
# Unique values: 88
# Min / Max: 0.42  /  80.0
# 5% / 95% percentile: 4.0  /  56.0
# ------------------ SibSp ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  0  -  608  ( 68.24 %)
# Unique values: 7
# Min / Max: 0  /  8
# Scew: 3.7
# ------------------ Parch ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  0  -  678  ( 76.09 %)
# Unique values: 7
# Min / Max: 0  /  6
# ------------------ Ticket ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  CA. 2343  -  7  ( 0.79 %)
# Unique values of: 681  ( 76.43 %)
#
# ------------------ Fare ---------------------
# Nan values:  0  ( 0.0 %)
# Most frequent:  8.046875  -  43  ( 4.83 %)
# Unique values: 242
# Min / Max: 0.0  /  512.5
# Scew: 4.79
# 5% / 95% percentile: 7.23  /  112.06
# ------------------ Cabin ---------------------
# Nan values:  687  ( 77.1 %)
# Most frequent:  G6  -  4  ( 1.96 %)
# Unique values of: 147  ( 72.06 %)
#
# ------------------ Embarked ---------------------
# Nan values:  2  ( 0.22 %)
# Most frequent:  S  -  644  ( 72.44 %)
# Unique values of: 3  ( 0.34 %)
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int16
# Survived       891 non-null int8
# Pclass         891 non-null int8
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float16
# SibSp          891 non-null int8
# Parch          891 non-null int8
# Ticket         891 non-null object
# Fare           891 non-null float16
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float16(2), int16(1), int8(4), object(5)
# memory usage: 43.6+ KB

# %%
train.skew()
# Out:
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Age            0.389160
# SibSp          3.695352
# Parch          2.749117
# Fare           4.789062
# dtype: float64
