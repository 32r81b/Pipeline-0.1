# %% [markdown]
# # Подгружаем библиотеки и данные

# %% [markdown]
# debug_mode служит индикатором, что работа с ноутбуком идет в режиме разработчика. В этом режиме для ускорения работы будут загружаться не все записи из датасета.

# %%
import pandas as pd
import numpy as np

from DS_stat import DS_stat
# %matplotlib inline

#debug_mode = False
debug_mode = True
pd.options.display.max_columns = None
KAGGLE_DIR = 'C:/Users/Acer/PycharmProjects/Pipeline 0.1/input/'
#KAGGLE_DIR = '../input/'

if debug_mode == True:
    train = pd.read_csv(KAGGLE_DIR + 'train_V2.csv', nrows=10000)
    test = pd.read_csv(KAGGLE_DIR + 'test_V2.csv', nrows=10000)
else:
    train = pd.read_csv(KAGGLE_DIR + 'train_V2.csv')
    test = pd.read_csv(KAGGLE_DIR + 'test_V2.csv')

target_column = 'winPlacePerc'
DS_stat(train, target_column, 'train')
# Out:
# Shape: 4446966  *  29
# First 5 rows from  train :
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  killPoints  kills  \
# 0         0.00      0              0      0         60        1241      0
# 1        91.47      0              0      0         57           0      0
# 2        68.00      0              0      0         47           0      0
# 3        32.90      0              0      0         75           0      0
# 4       100.00      0              0      0         45           0      1
#
# ...

# %%
train['winPlacePerc'].nan()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-bc69c8d12524> in <module>()
# ----> 1 train['winPlacePerc'].nan()
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'nan'
